# %%
import cluster_itom_comm_server

import threading

cluster_itom_comm_server.logging.basicConfig()
cluster_instance = cluster_itom_comm_server.Communication_Server(port_id = "0.0.0.0:3456")

#grpcServerThread = threading.Thread(target=cluster_itom_comm_server.Communication_Server(port_id = "0.0.0.0:3456"))
#grpcServerThread.start()
# Out:
# 2024-06-19 17:17:27.503127: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-19 17:17:27.503157: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-19 17:17:27.503598: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-19 17:17:27.507056: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
